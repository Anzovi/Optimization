# %%
import optimization
import numpy as np
import oracles
from utils import get_line_search_tool

# %%
from matplotlib import pyplot as plt
import itertools

# %%
def experiment_1_a():

  gammas = [10, 50, 100]
  tolerance_inners = [1e-5, 1e-7, 1e-9]

  def duality_gap_vs_iters(result):
    print("Итерации")
    duality_gap = history['duality_gap']
    x = list(range(len(history['duality_gap'])))
    plt.figure(figsize=(10,6))
    plt.plot(x, duality_gap)
    plt.title("Гарантируемая точность по зазору двойственности против числа итераций")
    plt.xlabel('Итераций')
    plt.ylabel('Duality gap')
    plt.yscale('log')
    plt.grid()
    plt.show()

  def duality_gap_vs_time(result):
    print("Время")
    duality_gap = history['duality_gap']
    x = np.array(history['time'])
    plt.figure(figsize=(10,6))
    plt.plot(x, duality_gap)
    plt.title("Гарантируемая точность по зазору двойственности против секунд")
    plt.xlabel('Секунды')
    plt.ylabel('Duality gap')
    plt.yscale('log')
    plt.grid()
    plt.show()

  for i, (gamma, tolerance_inner) in enumerate(itertools.product(gammas, tolerance_inners)):
    n = 250
    m = 500
    np.random.seed(11+i)
    print("--------------------------------")
    print("gamma: ", gamma, "tolerance_inner: ", tolerance_inner)
    A = np.random.uniform(low=-50, high=50, size=(m, n))
    b = np.random.uniform(low=-50, high=50, size=m)
    x_0 = np.zeros(n)

    histories = []
    u_0 = np.array([50] * n)

    _, _, _, history = optimization.barrier_method_lasso(A, b, 0.1, x_0, u_0, tolerance_inner = tolerance_inner, gamma = gamma, trace=True)


    duality_gap_vs_iters(history)
    duality_gap_vs_time(history)

# %%
experiment_1_a()
# Out:
# --------------------------------
# gamma:  10 tolerance_inner:  1e-05
# Итерации
# Время
# --------------------------------
# gamma:  10 tolerance_inner:  1e-07
# Итерации
# Время
# --------------------------------
# gamma:  10 tolerance_inner:  1e-09
# Итерации
# Время
# --------------------------------
# gamma:  50 tolerance_inner:  1e-05
# Итерации
# Время
# --------------------------------
# gamma:  50 tolerance_inner:  1e-07
# Итерации
# Время
# --------------------------------
# gamma:  50 tolerance_inner:  1e-09
# Итерации
# Время
# --------------------------------
# gamma:  100 tolerance_inner:  1e-05
# Итерации
# Время
# --------------------------------
# gamma:  100 tolerance_inner:  1e-07
# Итерации
# Время
# --------------------------------
# gamma:  100 tolerance_inner:  1e-09
# Итерации
# Время

# %%
def experiment_1_b():

  ns = [10, 100, 1000]
  ms = [100, 1000, 10000]
  regcoefs = [0.1, 0.5, 5]

  def duality_gap_vs_iters(result):
    print("Итерации")
    duality_gap = history['duality_gap']
    x = list(range(len(history['duality_gap'])))
    plt.figure(figsize=(10,6))
    plt.plot(x, duality_gap)
    plt.title("Гарантируемая точность по зазору двойственности против числа итераций")
    plt.xlabel('Итераций')
    plt.ylabel('Duality gap')
    plt.yscale('log')
    plt.grid()
    plt.show()

  def duality_gap_vs_time(result):
    print("Время")
    duality_gap = history['duality_gap']
    x = np.array(history['time'])
    plt.figure(figsize=(10,6))
    plt.plot(x, duality_gap)
    plt.title("Гарантируемая точность по зазору двойственности против секунд")
    plt.xlabel('Секунды')
    plt.ylabel('Duality gap')
    plt.yscale('log')
    plt.grid()
    plt.show()

  for i, (n, m, regcoef) in enumerate(itertools.product(ns, ms, regcoefs)):
    np.random.seed(11+i)
    print("--------------------------------")
    print(n, m, regcoef)
    print("n: ", n, "m: ", m, "regcoef: ", regcoef)
    A = np.random.uniform(low=-50, high=50, size=(m, n))
    b = np.random.uniform(low=-50, high=50, size=m)
    x_0 = np.zeros(n)

    u_0 = np.array([50] * n)

    _,_, _, history = optimization.barrier_method_lasso(A, b, regcoef, x_0, u_0, trace=True)

    duality_gap_vs_iters(history)
    duality_gap_vs_time(history)

# %%
# %%time
experiment_1_b()
# Out:
# --------------------------------
# 10 100 0.1
# n:  10 m:  100 regcoef:  0.1
# Итерации
# Время
# --------------------------------
# 10 100 0.5
# n:  10 m:  100 regcoef:  0.5
# Итерации
# Время
# --------------------------------
# 10 100 5
# n:  10 m:  100 regcoef:  5
# Итерации
# Время
# --------------------------------
# 10 1000 0.1
# n:  10 m:  1000 regcoef:  0.1
# Итерации
# Время
# --------------------------------
# 10 1000 0.5
# n:  10 m:  1000 regcoef:  0.5
# Итерации
# Время
# --------------------------------
# 10 1000 5
# n:  10 m:  1000 regcoef:  5
# Итерации
# Время
# --------------------------------
# 10 10000 0.1
# n:  10 m:  10000 regcoef:  0.1
# Итерации
# Время
# --------------------------------
# 10 10000 0.5
# n:  10 m:  10000 regcoef:  0.5
# Итерации
# Время
# --------------------------------
# 10 10000 5
# n:  10 m:  10000 regcoef:  5
# Итерации
# Время
# --------------------------------
# 100 100 0.1
# n:  100 m:  100 regcoef:  0.1
# Итерации
# Время
# ...
